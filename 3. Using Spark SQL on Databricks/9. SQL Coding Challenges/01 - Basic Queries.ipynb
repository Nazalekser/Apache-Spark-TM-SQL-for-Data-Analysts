# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# ## Create Tables
# Run the cell below to create tables for the questions in this notebook.

# %%
# %run ../Utilities/01-CreateTables
# Out:
# Declared the following table:
#   <li><span style="color:green; font-weight:bold">discounts</span></li>
# Declared the following table:
#   <li><span style="color:green; font-weight:bold">discounts2</span></li>

# %% [markdown]
# ## Question 1: Modify a Table
#
# ### Summary
# Modify the columns in table **`discounts`** to match the provided schema.
#
# ### Steps to Complete
# Write a SQL query that achieves the following:
# * Selects columns **`discountId`**, **`code`**, and **`price`**
# * Converts column **`discountId`** to type **`Long`**
# * Converts column **`price`** to type **`Double`**, multiplies it by 100 and then converts to type **`Integer`**
# * Saves this to a temporary view named **`q1Results`**

# %%
# %sql
describe discounts
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>retailer</td><td>string</td><td>null</td></tr><tr><td>discountId</td><td>string</td><td>null</td></tr><tr><td>code</td><td>string</td><td>null</td></tr><tr><td>price</td><td>string</td><td>null</td></tr><tr><td>active</td><td>string</td><td>null</td></tr><tr><td>createdAt</td><td>string</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
-- TODO Answer 1

create or replace temporary view q1Results as
select
  cast(discountId as Long),
  code,
  cast(cast(price as Double)*100 as int) as price
from
discounts;

describe discounts2;
select * from q1Results limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>discountId</th><th>code</th><th>price</th></tr></thead><tbody><tr><td>7719574101766138117</td><td>uJ0E8wHuZy6k</td><td>371867</td></tr><tr><td>5331833090881548283</td><td>a2jjCqprVrrB</td><td>939866</td></tr><tr><td>8666627108490644839</td><td>kpAiHRpMJ4V7</td><td>676856</td></tr><tr><td>7355965277554300691</td><td>j8MYcd13nMae</td><td>60303</td></tr><tr><td>7711997224946366674</td><td>pDg2iuVbZWCo</td><td>984961</td></tr></tbody></table></div>

# %% [markdown]
# ## Question 2: Basic Math and Drop Columns
#
# ### Summary
# Modify the columns in table **`discounts2`** to match the provided schema.
#
# ### Steps to complete
# Write a SQL query on the table **`discounts2`** that achieves the following:
# * Converts column **`active`** to type **`Boolean`**
# * Creates the column **`price`** by converting the column **`cents`** to type **`Double`** and dividing by 100
# * Drops the **`cents`** column
# * Saves this to a temporary view named **`q2Results`**

# %%
# %sql
describe discounts2;
select * from discounts2 limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>code</th><th>cents</th><th>active</th></tr></thead><tbody><tr><td>uJ0E8wHuZy6k</td><td>371867</td><td>false</td></tr><tr><td>a2jjCqprVrrB</td><td>939866</td><td>true</td></tr><tr><td>kpAiHRpMJ4V7</td><td>676856</td><td>false</td></tr><tr><td>j8MYcd13nMae</td><td>60303</td><td>true</td></tr><tr><td>pDg2iuVbZWCo</td><td>984961</td><td>true</td></tr></tbody></table></div>

# %%
# %sql
-- TODO Answer 2

create or replace temporary view q2Results as
select
  cast(active as Boolean), 
  cast(cents as Double)/100 as price
from
discounts2;

describe q2Results;
select * from q2Results tablesample (5 rows)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>active</th><th>price</th></tr></thead><tbody><tr><td>false</td><td>3718.67</td></tr><tr><td>true</td><td>9398.66</td></tr><tr><td>false</td><td>6768.56</td></tr><tr><td>true</td><td>603.03</td></tr><tr><td>true</td><td>9849.61</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
