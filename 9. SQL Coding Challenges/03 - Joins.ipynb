# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# ## Create Tables
# Run the cell below to create tables for the questions in this notebook.

# %%
# %run ../Utilities/03-CreateTables
# Out:
# Declared the following tables:
#   <li><span style="color:green; font-weight:bold">purchases</span> </li>
#   <li><span style="color:green; font-weight:bold">prices</span> </li>
# Declared the following tables:
#   <li><span style="color:green; font-weight:bold">discounts</span> </li>
#   <li><span style="color:green; font-weight:bold">products</span> </li>
# Declared the following tables:
#   <li><span style="color:green; font-weight:bold">stores</span> </li>
#   <li><span style="color:green; font-weight:bold">articles</span> </li>

# %% [markdown]
# ## Question 1: Joins
# ### Summary
# Perform a join of two tables **`purchases`** and **`prices`**.
#
# ### Steps to complete
# Write a SQL query that acheives the following:
# * Performs an inner join on two tables **`purchases`** and **`prices`** on the column **`itemId`**
# * Includes **only** 3 columns from the **`purchases`** table: **`transactionId`**, **`itemId`**, and **`value`**

# %%
# %sql
select * from purchases limit 5;
select * from prices limit 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>itemId</th><th>value</th></tr></thead><tbody><tr><td>1276630289051176466</td><td>5799.06</td></tr><tr><td>4564122576944698581</td><td>2573.49</td></tr><tr><td>5162133191347296340</td><td>1738.67</td></tr><tr><td>8506898554359980188</td><td>7472.67</td></tr><tr><td>4755055844677518678</td><td>5559.97</td></tr></tbody></table></div>

# %%
# %sql
--TODO  Answer 1

select transactionId, purchases.itemId, prices.value
from purchases
join prices on purchases.itemId = prices.itemId
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>transactionId</th><th>itemId</th><th>value</th></tr></thead><tbody><tr><td>3072</td><td>721798132696267935</td><td>7639.71</td></tr><tr><td>3073</td><td>5274937845866294368</td><td>593.41</td></tr><tr><td>3074</td><td>1184079848143569840</td><td>495.42</td></tr><tr><td>3075</td><td>6625090293814504906</td><td>8683.67</td></tr><tr><td>3076</td><td>4094462754234261730</td><td>1989.74</td></tr><tr><td>3077</td><td>3719347016390063358</td><td>9250.49</td></tr><tr><td>3078</td><td>1769676752351633708</td><td>4980.62</td></tr><tr><td>3079</td><td>4923240282664800042</td><td>9787.62</td></tr><tr><td>3080</td><td>1065748379340196706</td><td>9956.78</td></tr><tr><td>3081</td><td>8133423139325784203</td><td>3330.29</td></tr><tr><td>3082</td><td>6486956834050739311</td><td>5870.52</td></tr><tr><td>3083</td><td>6731528844322220428</td><td>8857.72</td></tr><tr><td>3084</td><td>4366274526267578237</td><td>1237.37</td></tr><tr><td>3085</td><td>8717195996064084746</td><td>8956.2</td></tr><tr><td>3086</td><td>2867802055978695093</td><td>9226.99</td></tr><tr><td>3087</td><td>885422506366073473</td><td>9314.65</td></tr><tr><td>3088</td><td>7014934439959245465</td><td>1730.19</td></tr><tr><td>3089</td><td>8056359990819431945</td><td>7970.74</td></tr><tr><td>3090</td><td>6230057124196484393</td><td>6875.97</td></tr><tr><td>3091</td><td>5333064286978485937</td><td>9447.1</td></tr><tr><td>3092</td><td>7739929356258313238</td><td>3517.16</td></tr><tr><td>3093</td><td>3322898171971964154</td><td>880.23</td></tr><tr><td>3094</td><td>3404001982068089422</td><td>165.27</td></tr><tr><td>3095</td><td>9014447560717302364</td><td>17.34</td></tr><tr><td>3096</td><td>2890289718244634959</td><td>7780.88</td></tr><tr><td>3097</td><td>8306731950828422592</td><td>8491.63</td></tr><tr><td>3098</td><td>2398223170441539958</td><td>1416.74</td></tr><tr><td>3099</td><td>3495572926906454073</td><td>9614.96</td></tr><tr><td>3100</td><td>8503627409220169485</td><td>9036.49</td></tr><tr><td>3101</td><td>3619355103818528768</td><td>1524.66</td></tr><tr><td>3102</td><td>2560779887343122312</td><td>5949.67</td></tr><tr><td>3103</td><td>7077088361778808690</td><td>9871.29</td></tr><tr><td>3104</td><td>3961996939750535154</td><td>6002.95</td></tr><tr><td>3105</td><td>4970136969175246837</td><td>3658.58</td></tr><tr><td>3106</td><td>450306036495192392</td><td>6091.42</td></tr><tr><td>3107</td><td>7003029498234046450</td><td>3553.38</td></tr><tr><td>3108</td><td>1653020852273539805</td><td>9409.63</td></tr><tr><td>3109</td><td>3192901165542885821</td><td>8993.27</td></tr><tr><td>3110</td><td>6422358423465665765</td><td>9485.16</td></tr><tr><td>3111</td><td>76070202845701394</td><td>7170.87</td></tr><tr><td>3112</td><td>2257614830408821405</td><td>4316.19</td></tr><tr><td>3113</td><td>8978084716018055195</td><td>3574.99</td></tr><tr><td>3114</td><td>8199017262098954622</td><td>7009.4</td></tr><tr><td>3115</td><td>8422356864749302710</td><td>883.04</td></tr><tr><td>3116</td><td>6551969707682418242</td><td>98.33</td></tr><tr><td>3117</td><td>8111657274358921976</td><td>5176.82</td></tr><tr><td>3118</td><td>4892918449173316999</td><td>1639.7</td></tr><tr><td>3119</td><td>7237647817679590074</td><td>3397.52</td></tr><tr><td>3120</td><td>2490821045563623304</td><td>1346.94</td></tr><tr><td>3121</td><td>5217267668775291532</td><td>2299.44</td></tr><tr><td>3122</td><td>5530926824673541318</td><td>3179.16</td></tr><tr><td>3123</td><td>2179371876389763412</td><td>1529.88</td></tr><tr><td>3124</td><td>4998470143004034646</td><td>6048.51</td></tr><tr><td>3125</td><td>9007206537167807700</td><td>9675.56</td></tr><tr><td>3126</td><td>8013530370399513938</td><td>2593.72</td></tr><tr><td>3127</td><td>8758638098536402</td><td>528.23</td></tr><tr><td>3128</td><td>3986805386227679106</td><td>1803.33</td></tr><tr><td>3129</td><td>702134455965875043</td><td>9781.48</td></tr><tr><td>3 ...

# %% [markdown]
# ## Question 2: Combine Tables
# ### Summary
# Perform an outer join on two tables **`discounts`** and **`products`** store the results into **`q2Results`** view.
#
# ### Steps to complete
# Write a SQL query that achieves the following:
# * Performs an outer join on table **`discounts`** and **`products`** on the **`itemName`** column
# * Ensures that the joined view only includes **one** **`itemName`** column that comes from the **`products`** table
#
#
# The final schema and DataFrame should contain the following columns, though not necessarily in this order:
#
# |column |type |
# |---|---|
# |itemName | string|
# |discountId | integer|
# |discountCode | string|
# |price | double|
# |active | boolean|
# |itemId | integer|
# |amount | integer|

# %%
# %sql
describe products
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>itemName</td><td>string</td><td>null</td></tr><tr><td>itemId</td><td>bigint</td><td>null</td></tr><tr><td>amount</td><td>bigint</td><td>null</td></tr></tbody></table></div>

# %%
# %sql
-- TODO  Answer 2

create or replace temporary view q2Results as
SELECT * FROM products 
OUTER JOIN discounts
USING (itemName);

describe q2Results
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>itemName</td><td>string</td><td>null</td></tr><tr><td>itemId</td><td>bigint</td><td>null</td></tr><tr><td>amount</td><td>bigint</td><td>null</td></tr><tr><td>discountId</td><td>bigint</td><td>null</td></tr><tr><td>discountCode</td><td>string</td><td>null</td></tr><tr><td>price</td><td>double</td><td>null</td></tr><tr><td>active</td><td>boolean</td><td>null</td></tr></tbody></table></div>

# %% [markdown]
# ## Question 3: Cross Join Tables
# ### Summary
# Perform a cross join on two tables **`stores`** and **`articles`**.
#
# ### Steps to complete
#
# * Perform a cross join on two tables **`stores`** and **`articles`**

# %%
# %sql
select * from stores
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>storeName</th><th>storeId</th></tr></thead><tbody><tr><td>Excepteur Aute</td><td>172</td></tr><tr><td>Aliqua Dolore</td><td>164</td></tr><tr><td>Excepteur </td><td>556</td></tr><tr><td>Pariatur Qui</td><td>213</td></tr></tbody></table></div>

# %%
# %sql
-- TODO  Answer 3

select *
from stores, articles
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>storeName</th><th>storeId</th><th>itemName</th><th>itemId</th><th>amount</th></tr></thead><tbody><tr><td>Excepteur Aute</td><td>172</td><td>Pariatur Incididunt</td><td>76589</td><td>473</td></tr><tr><td>Excepteur Aute</td><td>172</td><td>Aliqua Ea</td><td>67697</td><td>323</td></tr><tr><td>Excepteur Aute</td><td>172</td><td>Aliqua Minim</td><td>21837</td><td>190</td></tr><tr><td>Excepteur Aute</td><td>172</td><td>Excepteur Officia</td><td>12881</td><td>89</td></tr><tr><td>Excepteur Aute</td><td>172</td><td>Aliqua Dolore</td><td>26631</td><td>2199</td></tr><tr><td>Excepteur Aute</td><td>172</td><td>Ut Sit</td><td>23081</td><td>131</td></tr><tr><td>Aliqua Dolore</td><td>164</td><td>Pariatur Incididunt</td><td>76589</td><td>473</td></tr><tr><td>Aliqua Dolore</td><td>164</td><td>Aliqua Ea</td><td>67697</td><td>323</td></tr><tr><td>Aliqua Dolore</td><td>164</td><td>Aliqua Minim</td><td>21837</td><td>190</td></tr><tr><td>Aliqua Dolore</td><td>164</td><td>Excepteur Officia</td><td>12881</td><td>89</td></tr><tr><td>Aliqua Dolore</td><td>164</td><td>Aliqua Dolore</td><td>26631</td><td>2199</td></tr><tr><td>Aliqua Dolore</td><td>164</td><td>Ut Sit</td><td>23081</td><td>131</td></tr><tr><td>Excepteur </td><td>556</td><td>Pariatur Incididunt</td><td>76589</td><td>473</td></tr><tr><td>Excepteur </td><td>556</td><td>Aliqua Ea</td><td>67697</td><td>323</td></tr><tr><td>Excepteur </td><td>556</td><td>Aliqua Minim</td><td>21837</td><td>190</td></tr><tr><td>Excepteur </td><td>556</td><td>Excepteur Officia</td><td>12881</td><td>89</td></tr><tr><td>Excepteur </td><td>556</td><td>Aliqua Dolore</td><td>26631</td><td>2199</td></tr><tr><td>Excepteur </td><td>556</td><td>Ut Sit</td><td>23081</td><td>131</td></tr><tr><td>Pariatur Qui</td><td>213</td><td>Pariatur Incididunt</td><td>76589</td><td>473</td></tr><tr><td>Pariatur Qui</td><td>213</td><td>Aliqua Ea</td><td>67697</td><td>323</td></tr><tr><td>Pariatur Qui</td><td>213</td><td>Aliqua Minim</td><td>21837</td><td>190</td></tr><tr><td>Pariatur Qui</td><td>213</td><td>Excepteur Officia</td><td>12881</td><td>89</td></tr><tr><td>Pariatur Qui</td><td>213</td><td>Aliqua Dolore</td><td>26631</td><td>2199</td></tr><tr><td>Pariatur Qui</td><td>213</td><td>Ut Sit</td><td>23081</td><td>131</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
